# %%
import numpy as np
from libitmal import dataloaders_v3 as dataloaders

X, y = dataloaders.MNIST_GetDataSet(fetchmode=False)

X = X.reshape(70000, 784)
#X_norm = X*np.float32(1)   # NOTE: ups, remembered convert to float but forgot scale 
X_norm = X/np.float32(255) # NOTE: remembered convert to float and scale 

print(f"X_norm.shape={X_norm.shape}")
print(f"  type(X_norm[0][0])={type(X_norm[0][0])}")
print(f"  X_norm.dtype={X_norm.dtype}")
print(f"  np.max(X_norm)={np.max(X_norm)}")
print(f"  np.min(X_norm)={np.min(X_norm)}")

from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3, random_state=42)

y_train_cat = to_categorical(y_train)
y_test_cat  = to_categorical(y_test)
# Out:
# X_norm.shape=(70000, 784)
#   type(X_norm[0][0])=<class 'numpy.float32'>
#   X_norm.dtype=float32
#   np.max(X_norm)=1.0
#   np.min(X_norm)=0.0

# %%
from time import time

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD, Nadam
from keras.layers.normalization import BatchNormalization
#from keras.backend import batch_normalization

def AddLayer(model, units, add_normalization=False, dropout_rate=-1):
    model.add(Dense(units=units, 
                activation="elu", 
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     
    if add_normalization:
        model.add(BatchNormalization())
    if dropout_rate>=0:
        model.add(Dropout(rate=dropout_rate))


model = Sequential()
#model.add(BatchNormalization())
model.add(Dense(input_dim=(784), units=20, 
                activation="elu", 
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     
#model.add(BatchNormalization())
#model.add(Dropout(rate=DROPOUT_RATE))

# Grp10: 20, 50, 70, 100, 70, 50, 20
AddLayer(model, 50)
AddLayer(model, 70)
AddLayer(model, 100)
AddLayer(model, 70)
AddLayer(model, 50)
AddLayer(model, 20)

model.add(Dense(units=10, 
                activation="softmax",
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     

def ModelCompile(model):
    #optimizer = Adam (lr=0.1) # NOTE: will fail miserable for lr=0.1
    #optimizer = Adam (lr=0.01) 
    #optimizer = Nadam(lr=0.002) # NOTE: Nadam=Nesterov Adam optimizer.
    optimizer = SGD  (lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
          
    model.compile(loss='categorical_crossentropy', 
            optimizer=optimizer, 
             metrics=['categorical_crossentropy',
                       'categorical_accuracy',
                       'mean_squared_error',
                       'mean_absolute_error'])
    try:
        model.summary()
    except:
        print("WARNING: model.summary() failed, cannot print models wiht BatchNormalization() layers before fit")
    

def PrintScore(model, X_test, y_test_cat, t):
    #print(history.history)
    score = model.evaluate(X_test, y_test_cat, verbose=0)
    print(f"Training time: {t:0.1f} sec")
    print(f"Test loss:     {score[0]}") # loss is score 0 by definition?
    print(f"Test accuracy: {score[2]}")
    #print(f"All scores in history: {score}")
    
# Train
VERBOSE     = 1
EPOCHS      = 20
DROPOUT_RATE= 0.1

ModelCompile(model)

start = time()
history = model.fit(X_train, y_train_cat, 
                    validation_data=(X_test, y_test_cat), 
                    epochs=EPOCHS, 
                    verbose=VERBOSE)
t = time()-start

PrintScore(model, X_test, y_test_cat, t)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 20)                15700
# _________________________________________________________________
# dense_18 (Dense)             (None, 50)                1050
# _________________________________________________________________
# dense_19 (Dense)             (None, 70)                3570
# _________________________________________________________________
# dense_20 (Dense)             (None, 100)               7100
# _________________________________________________________________
# dense_21 (Dense)             (None, 70)                7070
# _________________________________________________________________
# dense_22 (Dense)             (None, 50)                3550
# _________________________________________________________________
# dense_23 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                210
# =================================================================
# Total params: 39,270
# Trainable params: 39,270
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49000 samples, validate on 21000 samples
# Epoch 1/20
# 49000/49000 [==============================] - 3s 66us/step - loss: 0.3165 - categorical_crossentropy: 0.3165 - categorical_accuracy: 0.9031 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0277 - val_loss: 0.2058 - val_categorical_crossentropy: 0.2058 - val_categorical_accuracy: 0.9383 - val_mean_squared_error: 0.0093 - val_mean_absolute_error: 0.0175
# Epoch 2/20
# 49000/49000 [==============================] - 3s 62us/step - loss: 0.1753 - categorical_crossentropy: 0.1753 - categorical_accuracy: 0.9475 - mean_squared_error: 0.0080 - mean_absolute_error: 0.0155 - val_loss: 0.1832 - val_categorical_crossentropy: 0.1832 - val_categorical_accuracy: 0.9461 - val_mean_squared_error: 0.0083 - val_mean_absolute_error: 0.0152
# Epoch 3/20
# 49000/49000 [==============================] - 3s 55us/step - loss: 0.1412 - categorical_crossentropy: 0.1412 - categorical_accuracy: 0.9569 - mean_squared_error: 0.0065 - mean_absolute_error: 0.0126 - val_loss: 0.1670 - val_categorical_crossentropy: 0.1670 - val_categorical_accuracy: 0.9492 - val_mean_squared_error: 0.0077 - val_mean_absolute_error: 0.0145
# Epoch 4/20
# 49000/49000 [==============================] - 3s 54us/step - loss: 0.1219 - categorical_crossentropy: 0.1219 - categorical_accuracy: 0.9614 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0110 - val_loss: 0.1699 - val_categorical_crossentropy: 0.1699 - val_categorical_accuracy: 0.9526 - val_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0126
# Epoch 5/20
# 49000/49000 [==============================] - 3s 62us/step - loss: 0.1058 - categorical_crossentropy: 0.1058 - categorical_accuracy: 0.9673 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0095 - val_loss: 0.1271 - val_categorical_crossentropy: 0.1271 - val_categorical_accuracy: 0.9623 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0107
# Epoch 6/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0955 - categorical_crossentropy: 0.0955 - categorical_accuracy: 0.9708 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0087 - val_loss: 0.1376 - val_categorical_crossentropy: 0.1376 - val_categorical_accuracy: 0.9608 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0107
# Epoch 7/20
# 49000/49000 [==============================] - 3s 54us/step - loss: 0.0853 - categorical_crossentropy: 0.0853 - categorical_accuracy: 0.9736 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0078 - val_loss: 0.1335 - val_categorical_crossentropy: 0.1335 - val_categorical_accuracy: 0.9618 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0102
# Epoch 8/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0798 - categorical_crossentropy: 0.0798 - categorical_accuracy: 0.9754 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0073 - val_loss: 0.1389 - val_categorical_crossentropy: 0.1389 - val_categorical_accuracy: 0.9614 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0099
# Epoch 9/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0764 - categorical_crossentropy: 0.0764 - categorical_accuracy: 0.9753 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0071 - val_loss: 0.1312 - val_categorical_crossentropy: 0.1312 - val_categorical_accuracy: 0.9629 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0090
# Epoch 10/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0686 - categorical_crossentropy: 0.0686 - categorical_accuracy: 0.9787 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0064 - val_loss: 0.1164 - val_categorical_crossentropy: 0.1164 - val_categorical_accuracy: 0.9676 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0085
# Epoch 11/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0638 - categorical_crossentropy: 0.0638 - categorical_accuracy: 0.9796 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0060 - val_loss: 0.1258 - val_categorical_crossentropy: 0.1258 - val_categorical_accuracy: 0.9671 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0083
# Epoch 12/20
# 49000/49000 [==============================] - 3s 57us/step - loss: 0.0595 - categorical_crossentropy: 0.0595 - categorical_accuracy: 0.9808 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0055 - val_loss: 0.1397 - val_categorical_crossentropy: 0.1397 - val_categorical_accuracy: 0.9636 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0096
# Epoch 13/20
# 49000/49000 [==============================] - 3s 58us/step - loss: 0.0573 - categorical_crossentropy: 0.0573 - categorical_accuracy: 0.9815 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0053 - val_loss: 0.1355 - val_categorical_crossentropy: 0.1355 - val_categorical_accuracy: 0.9634 - val_mean_squared_error: 0.0058 - val_mean_absolute_error: 0.0091
# Epoch 14/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0554 - categorical_crossentropy: 0.0554 - categorical_accuracy: 0.9825 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0051 - val_loss: 0.1581 - val_categorical_crossentropy: 0.1581 - val_categorical_accuracy: 0.9595 - val_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0094
# Epoch 15/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0533 - categorical_crossentropy: 0.0533 - categorical_accuracy: 0.9821 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0050 - val_loss: 0.1348 - val_categorical_crossentropy: 0.1348 - val_categorical_accuracy: 0.9663 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0082
# Epoch 16/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0491 - categorical_crossentropy: 0.0491 - categorical_accuracy: 0.9844 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0046 - val_loss: 0.1416 - val_categorical_crossentropy: 0.1416 - val_categorical_accuracy: 0.9653 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0081
# Epoch 17/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0482 - categorical_crossentropy: 0.0482 - categorical_accuracy: 0.9847 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0044 - val_loss: 0.1466 - val_categorical_crossentropy: 0.1466 - val_categorical_accuracy: 0.9645 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0086
# Epoch 18/20
# 49000/49000 [==============================] - 3s 53us/step - loss: 0.0478 - categorical_crossentropy: 0.0478 - categorical_accuracy: 0.9846 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0045 - val_loss: 0.1343 - val_categorical_crossentropy: 0.1343 - val_categorical_accuracy: 0.9680 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0076
# Epoch 19/20
# 49000/49000 [==============================] - 2s 51us/step - loss: 0.0421 - categorical_crossentropy: 0.0421 - categorical_accuracy: 0.9861 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0040 - val_loss: 0.1623 - val_categorical_crossentropy: 0.1623 - val_categorical_accuracy: 0.9612 - val_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0087
# Epoch 20/20
# 49000/49000 [==============================] - 2s 51us/step - loss: 0.0401 - categorical_crossentropy: 0.0401 - categorical_accuracy: 0.9872 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0038 - val_loss: 0.1391 - val_categorical_crossentropy: 0.1391 - val_categorical_accuracy: 0.9669 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0078
# Training time: 54.2 sec
# Test loss:     0.13913622534949155
# Test accuracy: 0.9668571428571429

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def MakePlots(history):
    N=3
    FX=60
    FY=4
    A=0.4
    S=4

    # Plot loss
    plt.figure(figsize=(FX, FY))
    ax = plt.subplot(1, N, 1)
    plt.plot(history.history["loss"]    , "b--x", markerfacecolor=(0, 0, 1, A), markersize=S)
    plt.plot(history.history["val_loss"], "g-s" , markerfacecolor=(0, 1, 0, A), markersize=S)
    plt.legend(loc="best", labels=("loss(train)","loss(val)"))
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.xlim((0, EPOCHS-1))
    plt.title("Loss-vs-epoch plot")
    plt.show()

    # Plot all metrics + loss
    plt.figure(figsize=(FX, FY))
    ax = plt.subplot(1, N, 2)
    plt.plot(history.history["mean_squared_error"],      "r:x", markerfacecolor=(1, 0, 0, A), markersize=S)
    plt.plot(history.history["val_mean_squared_error"],  "r-x", markerfacecolor=(1, 0, 0, A), markersize=S)
    plt.plot(history.history["mean_absolute_error"],     "b:o", markerfacecolor=(0, 0, 1, A), markersize=S)
    plt.plot(history.history["val_mean_absolute_error"], "b-o", markerfacecolor=(0, 0, 1, A), markersize=S)
    plt.xlabel("epoch")
    plt.ylabel("error")
    plt.xlim((0, EPOCHS-1))
    plt.legend(loc="best", labels=("mean_squared_error(train)",  "mean_squared_error(val)", 
                                   "mean_absolute_error(train)", "mean_absolute_error(val)"))
    plt.title("Error-vs-epoch plot")
    plt.show()

    # Plot accuracy
    plt.figure(figsize=(FX, FY))
    ax = plt.subplot(1, N, 3)
    plt.plot(history.history["categorical_accuracy"],     "m-x", markerfacecolor=(1, 0, 1, A), markersize=S)
    plt.plot(history.history["val_categorical_accuracy"], "m:x", markerfacecolor=(1, 0, 1, A), markersize=S)
    ax.set_ylim([0,1])
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.xlim((0, EPOCHS-1))
    plt.legend(loc="lower right", labels=("accuracy,train","accuracy,val"))
    plt.title("Accuracy-vs-epoch plot")
    plt.show()

MakePlots(history)

# %%
model = Sequential()
model.add(Dense(input_dim=(784), units=20, 
                activation="elu", 
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     
# Grp10: 20, 50, 70, 100, 70, 50, 20
AddLayer(model, 50,  dropout_rate=DROPOUT_RATE)
AddLayer(model, 70,  dropout_rate=DROPOUT_RATE)
AddLayer(model, 100, dropout_rate=DROPOUT_RATE)
AddLayer(model, 70,  dropout_rate=DROPOUT_RATE)
AddLayer(model, 50,  dropout_rate=DROPOUT_RATE)
AddLayer(model, 20,  dropout_rate=DROPOUT_RATE)
model.add(Dense(units=10, 
                activation="softmax",
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     

ModelCompile(model)

start = time()
history = model.fit(X_train, y_train_cat, 
                    validation_data=(X_test, y_test_cat), 
                    epochs=EPOCHS, 
                    verbose=VERBOSE)
t = time()-start

PrintScore(model, X_test, y_test_cat, t)
MakePlots(history)
# Out:
# WARNING:tensorflow:From /home/cef/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 20)                15700
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                1050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 70)                3570
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 70)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               7100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 70)                7070
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 70)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                3550
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                210
# =================================================================
# Total params: 39,270
# Trainable params: 39,270
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49000 samples, validate on 21000 samples
# Epoch 1/3
# 49000/49000 [==============================] - 4s 86us/step - loss: 0.5045 - categorical_crossentropy: 0.5045 - categorical_accuracy: 0.8496 - mean_squared_error: 0.0219 - mean_absolute_error: 0.0431 - val_loss: 0.2476 - val_categorical_crossentropy: 0.2476 - val_categorical_accuracy: 0.9306 - val_mean_squared_error: 0.0106 - val_mean_absolute_error: 0.0181
# Epoch 2/3
# 49000/49000 [==============================] - 3s 66us/step - loss: 0.2635 - categorical_crossentropy: 0.2635 - categorical_accuracy: 0.9270 - mean_squared_error: 0.0112 - mean_absolute_error: 0.0223 - val_loss: 0.2385 - val_categorical_crossentropy: 0.2385 - val_categorical_accuracy: 0.9312 - val_mean_squared_error: 0.0105 - val_mean_absolute_error: 0.0171
# Epoch 3/3
# 15616/49000 [========>.....................] - ETA: 1s - loss: 0.2333 - categorical_crossentropy: 0.2333 - categorical_accuracy: 0.9355 - mean_squared_error: 0.0099 - mean_absolute_error: 0.0197
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d078fb49d374> in <module>
#      22                     validation_data=(X_test, y_test_cat),
#      23                     epochs=EPOCHS,
# ---> 24                     verbose=VERBOSE)
#      25 t = time()-start
#      26
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
   # NOTE: ups, remembered convert to float but forgot scale 
X_norm = X*np.float32(1) # NOTE: remembered convert to float and scale 

print(f"X.shape={X.shape}")
print(f"  type(X_norm[0][0])={type(X_norm[0][0])}")
print(f"  X_norm.dtype={X_norm.dtype}")
print(f"  np.max(X_norm)={np.max(X_norm)}")
print(f"  np.min(X_norm)={np.min(X_norm)}")

start = time()
history = model.fit(X_train, y_train_cat, 
                    validation_data=(X_test, y_test_cat), 
                    epochs=EPOCHS, 
                    verbose=VERBOSE)
t = time()-start

PrintScore(model, X_test, y_test_cat, t)
MakePlots(history)

# %%
model = Sequential()
model.add(Dense(input_dim=(784), units=20, 
                activation="elu", 
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     
# Grp10: 20, 50, 70, 100, 70, 50, 20
AddLayer(model, 50,  add_normalization=True)
AddLayer(model, 70,  add_normalization=True)
AddLayer(model, 100, add_normalization=True)
AddLayer(model, 70,  add_normalization=True)
AddLayer(model, 50,  add_normalization=True)
AddLayer(model, 20,  add_normalization=True)
model.add(Dense(units=10, 
                activation="softmax",
                kernel_initializer="he_normal",  
                bias_initializer  ="he_normal"))     

ModelCompile(model)

start = time()
history = model.fit(X_train, y_train_cat, 
                    validation_data=(X_test, y_test_cat), 
                    epochs=EPOCHS, 
                    verbose=VERBOSE)
t = time()-start

PrintScore(model, X_test, y_test_cat, t)
MakePlots(history)
